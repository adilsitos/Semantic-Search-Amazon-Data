# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# This notebook contain the metadata of books from amazon. This data can be found at the [Amazon Review Data](https://nijianmo.github.io/amazon/index.html). Since this is the first analysis, we'll do only with some samples (100000).

# %%
import pandas as pd
import json
import gzip

# %% [markdown]
# The following function will open the json file and insert the data to a python list

# %%
def create_data_samples(size=10000):
    data = []
    i = 0

    with gzip.open('meta_Books.json.gz') as f:
        for l in f:
            if(i == size): # limiting to 100000 rows
                break
            data.append(json.loads(l.strip()))
            i += 1
    return data

# %%
data = create_data_samples(size=100000)
print(len(data))
print(data[500])
# Out:
# 100000
# {'category': [], 'tech1': '', 'description': ['Very clean dust jacket. No markings in book. A find example of this book.'], 'fit': '', 'title': 'The memoirs of Princess Alice, Duchess of Gloucester', 'also_buy': ['1909771155', '1910198129', '1546960376', '1910198137'], 'tech2': '', 'brand': 'Alice', 'feature': [], 'rank': '1,575,603 in Books (', 'also_view': ['0312302398', '1524763136'], 'main_cat': 'Books', 'similar_item': '', 'date': '', 'price': '$8.23', 'asin': '0002166461', 'imageURL': [], 'imageURLHighRes': []}

# %% [markdown]
# The book subsection has a lot of samples, so the data here is limited to just 10000, but you can set any value in the parameter on `create_data_samples`.

# %%
df = pd.DataFrame.from_dict(data)
df.shape
# Out:
# (100000, 18)

# %%
df.head()
# Out:
#                                             category tech1  \
# 0                                                 []
# 1  [Books, New, Used & Rental Textbooks, Medicine...
# 2                 [Books, Arts & Photography, Music]
# 3                 [Books, Arts & Photography, Music]
# 4                                                 []
#
#                                          description fit  \
# 0  [It is a biology book with God&apos;s perspect...
# 1                                                 []
# 2  [Discography of American Punk, Hardcore, and P...
# 3  [This is a collection of classic gospel hymns ...
# 4                                                 []
#
#                                                title  \
# 0  Biology Gods Living Creation Third Edition 10 ...
# 1  Mksap 16 Audio Companion: Medical Knowledge Se...
# 2  Flex! Discography of North American Punk, Hard...
# 3         Heavenly Highway Hymns: Shaped-Note Hymnal
# 4  Georgina Goodman Nelson Womens Size 8.5 Purple...
#
#                                             also_buy tech2             brand  \
# 0  [0669009075, B000K2P5SA, B00MD4G2N0, B000ASIPT...            Keith Graham
# 1                                                 []                     Acp
# 2                                                 []        Burkhard Jarisch
# 3                                                 []           Stamps/Baxter
# 4                                                 []
#
#   feature                   rank  \
# 0      []   1,349,781 in Books (
# 1      []   1,702,625 in Books (
# 2      []   6,291,012 in Books (
# 3      []   2,384,057 in Books (
# 4      []  11,735,726 in Books (
#
#                                            also_view main_cat similar_item  \
# 0  [0019777701, B000AUCX7I, B000K2P5SA, B001CK63X...    Books
# 1                           [B01MUCYEV7, B01KUGTY6O]    Books
# 2                                                 []    Books
# 3  [0006180116, 0996092730, B000QFOGY0, B06WWKNDL...    Books
# 4                                                 []    Books
#
#   date    price        asin imageURL imageURLHighRes
# 0        $39.94  0000092878       []              []
# 1                000047715X       []              []
# 2       $199.99  0000004545       []              []
# 3                0000013765       []              []
# 4       $164.10  0000000116       []              []

# %%
df.head(1).also_buy.values
# Out:
# array([list(['0669009075', 'B000K2P5SA', 'B00MD4G2N0', 'B000ASIPTK', '0130508470', '1892427524', '0321567919', 'B000BJBH20', '0547484631', 'B000HAJTQO', 'B000AUCX7I', '0130365645', 'B000BI1Y2O', '0395976715', '052817729X', '1579246443', 'B001CK63XK', '1591669847', '0395879884', '836585161X', 'B01J2F9BH6', 'B00KYEHR4E', '158008141X', '1857928393', '0927545829', 'B015AR0RA0', 'B000TVHHRE', '0865167990', '1579246052', 'B003NXXVD4', 'B000OH6AX0', '061802087X', 'B000NU2X02', '0743252012'])],
#       dtype=object)

# %% [markdown]
# ## Creating the dataset to NLP model

# %% [markdown]
# In this first approach will be using just three columns from the metadata:
#  - title
#  - asin (id of the product)
#  - also_buy ()
#
# So we need to remove the other columns:

# %%
df = df.drop(columns=['category', 'tech1', 'description', 'fit', 'also_view', 
              'main_cat', 'imageURL', 'imageURLHighRes','tech2', 
              'brand', 'feature', 'rank', 'similar_item', 'date', 'price'])
df.head()
# Out:
#                                                title  \
# 0  Biology Gods Living Creation Third Edition 10 ...
# 1  Mksap 16 Audio Companion: Medical Knowledge Se...
# 2  Flex! Discography of North American Punk, Hard...
# 3         Heavenly Highway Hymns: Shaped-Note Hymnal
# 4  Georgina Goodman Nelson Womens Size 8.5 Purple...
#
#                                             also_buy        asin
# 0  [0669009075, B000K2P5SA, B00MD4G2N0, B000ASIPT...  0000092878
# 1                                                 []  000047715X
# 2                                                 []  0000004545
# 3                                                 []  0000013765
# 4                                                 []  0000000116

# %%
df.shape
# Out:
# (100000, 3)

# %% [markdown]
# Method to create a json with a dataframe:

# %%
def create_json(dataframe, file_name: str):
    dataframe.to_json(r'./{file_name}.json', orient='records')

# %% [markdown]
# Deleting row with books without a title:

# %%
df[df.title == '']
# Out:
# Empty DataFrame
# Columns: [title, also_buy, asin]
# Index: []

# %%
df[df.title == ''].shape
# Out:
# (5, 3)

# %%
df = df.drop(df[df.title == ''].index)
df.shape
# Out:
# (99995, 3)

# %%
create_json(df, 'metadata_100000')

# %%
also_buy = str(df.head(2).also_buy.values)
len(also_buy)
also_buy.split(',')
# Out:
# ["[list(['0669009075'",
#  " 'B000K2P5SA'",
#  " 'B00MD4G2N0'",
#  " 'B000ASIPTK'",
#  " '0130508470'",
#  " '1892427524'",
#  " '0321567919'",
#  " 'B000BJBH20'",
#  " '0547484631'",
#  " 'B000HAJTQO'",
#  " 'B000AUCX7I'",
#  " '0130365645'",
#  " 'B000BI1Y2O'",
#  " '0395976715'",
#  " '052817729X'",
#  " '1579246443'",
#  " 'B001CK63XK'",
#  " '1591669847'",
#  " '0395879884'",
#  " '836585161X'",
#  " 'B01J2F9BH6'",
#  " 'B00KYEHR4E'",
#  " '158008141X'",
#  " '1857928393'",
#  " '0927545829'",
#  " 'B015AR0RA0'",
#  " 'B000TVHHRE'",
#  " '0865167990'",
#  " '1579246052'",
#  " 'B003NXXVD4'",
#  " 'B000OH6AX0'",
#  " '061802087X'",
#  " 'B000NU2X02'",
#  " '0743252012'])\n list([])]"]

# %% [markdown]
# Now we have the json in our `data`, we can save it as a json file with `df.to_json` method from pandas.

# %% [markdown]
# Removing books that does't have any category

# %%
df[df.fit == '']
# Out:
#                                                 category tech1  \
# 1      [Books, New, Used & Rental Textbooks, Medicine...
# 2                     [Books, Arts & Photography, Music]
# 3                     [Books, Arts & Photography, Music]
# 5      [Books, New, Used & Rental Textbooks, Medicine...
# 6                       [Books, Medical Books, Medicine]
# ...                                                  ...   ...
# 99994               [Books, Business & Money, Economics]
# 99996                         [Books, History, Military]
# 99997     [Books, Literature & Fiction, Women's Fiction]
# 99998                  [Books, Literature &amp; Fiction]
# 99999          [Books, Business &amp; Money, Industries]
#
#                                              description fit  \
# 1                                                     []
# 2      [Discography of American Punk, Hardcore, and P...
# 3      [This is a collection of classic gospel hymns ...
# 5                               [Brand new; never used.]
# 6      [Flash cards used with accompany MKSAP 15 audi...
# ...                                                  ...  ..
# 99994  [You know the people in this book. You'll reme...
# 99996  [Colonel Richard Kemp is a former Commanding O...
# 99997  [Julia Llewellyn is the author of The Love Tra...
# 99998  [Judith Summers is the author of four novels, ...
# 99999  ['A surefire bet' The Observer 'The Hot Topic ...
#
#                                                    title  \
# 1      Mksap 16 Audio Companion: Medical Knowledge Se...
# 2      Flex! Discography of North American Punk, Hard...
# 3             Heavenly Highway Hymns: Shaped-Note Hymnal
# 5      Principles of Analgesic Use in the Treatment o...
# 6                               MKSAP 15 Audio Companion
# ...                                                  ...
# 99994  Chinese Whispers: The True Story Behind Britai...
# 99996                                   Attack State Red
# 99997                        Ten Minutes To Fall In Love
# 99998  Badness Of King George,The: Fostering The Resc...
# 99999                                      Binge Trading
#
#                                                 also_buy tech2  \
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 5                               [0323056962, 0123979285]
# 6                                                     []
# ...                                                  ...   ...
# 99994                                                 []
# 99996  [1476773084, 0007296649, 009194855X, 000725780...
# 99997                                                 []
# 99998                                       [0141032235]
# 99999                                                 []
#
#                                      brand feature                   rank  \
# 1                                      Acp      []   1,702,625 in Books (
# 2                         Burkhard Jarisch      []   6,291,012 in Books (
# 3                            Stamps/Baxter      []   2,384,057 in Books (
# 5                    American Pain Society      []   2,906,939 in Books (
# 6                                      ACP      []   2,236,549 in Books (
# ...                                    ...     ...                    ...
# 99994   Visit Amazon's Hsiao-Hung Pai Page      []   3,861,504 in Books (
# 99996                     Col Richard Kemp      []   2,293,499 in Books (
# 99997  Visit Amazon's Julia Llewellyn Page      []  13,478,874 in Books (
# 99998                       Summers Judith      []   3,168,897 in Books (
# 99999    Visit Amazon's Seth Freedman Page      []   5,845,635 in Books (
#
#                                                also_view main_cat  \
# 1                               [B01MUCYEV7, B01KUGTY6O]    Books
# 2                                                     []    Books
# 3      [0006180116, 0996092730, B000QFOGY0, B06WWKNDL...    Books
# 5                               [0323056962, 0521879272]    Books
# 6                                                     []    Books
# ...                                                  ...      ...
# 99994                                                 []    Books
# 99996                                                 []    Books
# 99997                                                 []    Books
# 99998                                                 []    Books
# 99999                                                 []    Books
#
#       similar_item date    price        asin imageURL imageURLHighRes
# 1                                 000047715X       []              []
# 2                        $199.99  0000004545       []              []
# 3                                 0000013765       []              []
# 5                                 0000555010       []              []
# 6                                 0000477141       []              []
# ...            ...  ...      ...         ...      ...             ...
# 99994                     $37.19  0141035684       []              []
# 99996                     $20.90  0141041633       []              []
# 99997                     $31.00  0141048174       []              []
# 99998                     $13.66  0141046473       []              []
# 99999                     $14.10  0141043644       []              []
#
# [92989 rows x 18 columns]

# %%
df = df.drop(df[df.category.map(len) == 0].index)
df.head()
# Out:
#                                             category tech1  \
# 1  [Books, New, Used & Rental Textbooks, Medicine...
# 2                 [Books, Arts & Photography, Music]
# 3                 [Books, Arts & Photography, Music]
# 5  [Books, New, Used & Rental Textbooks, Medicine...
# 6                   [Books, Medical Books, Medicine]
#
#                                          description fit  \
# 1                                                 []
# 2  [Discography of American Punk, Hardcore, and P...
# 3  [This is a collection of classic gospel hymns ...
# 5                           [Brand new; never used.]
# 6  [Flash cards used with accompany MKSAP 15 audi...
#
#                                                title  \
# 1  Mksap 16 Audio Companion: Medical Knowledge Se...
# 2  Flex! Discography of North American Punk, Hard...
# 3         Heavenly Highway Hymns: Shaped-Note Hymnal
# 5  Principles of Analgesic Use in the Treatment o...
# 6                           MKSAP 15 Audio Companion
#
#                    also_buy tech2                  brand feature  \
# 1                        []                          Acp      []
# 2                        []             Burkhard Jarisch      []
# 3                        []                Stamps/Baxter      []
# 5  [0323056962, 0123979285]        American Pain Society      []
# 6                        []                          ACP      []
#
#                    rank                                          also_view  \
# 1  1,702,625 in Books (                           [B01MUCYEV7, B01KUGTY6O]
# 2  6,291,012 in Books (                                                 []
# 3  2,384,057 in Books (  [0006180116, 0996092730, B000QFOGY0, B06WWKNDL...
# 5  2,906,939 in Books (                           [0323056962, 0521879272]
# 6  2,236,549 in Books (                                                 []
#
#   main_cat similar_item date    price        asin imageURL imageURLHighRes
# 1    Books                             000047715X       []              []
# 2    Books                    $199.99  0000004545       []              []
# 3    Books                             0000013765       []              []
# 5    Books                             0000555010       []              []
# 6    Books                             0000477141       []              []

# %%
df[df.brand.map(len) == 0]
# Out:
#                                                 category tech1  \
# 35     [Books, Reference, Writing, Research & Publish...
# 79                    [Books, Arts & Photography, Music]
# 80                    [Books, Arts & Photography, Music]
# 87                    [Books, Arts & Photography, Music]
# 90             [Books, Christian Books & Bibles, Bibles]
# ...                                                  ...   ...
# 91842  [Books, Computers &amp; Technology, Operating ...
# 91953  [Books, Humor &amp; Entertainment, Puzzles &am...
# 99343  [Books, Humor &amp; Entertainment, Puzzles &am...
# 99776                     [Books, Biographies & Memoirs]
# 99882  [Books, Literature & Fiction, Action & Adventure]
#
#                                              description fit  \
# 35                                                    []
# 79                                                    []
# 80                                                    []
# 87                                                    []
# 90                                                    []
# ...                                                  ...  ..
# 91842                 [Book by Christine M. Gianone, , ]
# 91953  [1983 edition. Book shows age. Underlining and...
# 99343                              [Book by unknown, , ]
# 99776                                                 []
# 99882                                                 []
#
#                                                    title      also_buy tech2  \
# 35     Everyday Writer, The - Andrea Lunsford - Other...            []
# 79                                   Concert Piano Solos            []
# 80                   20 Black Gospel Favorites, Volume 3            []
# 87                                   Sonatas - For Piano            []
# 90                       Polish New Testament and Psalms            []
# ...                                                  ...           ...   ...
# 91842  Using Ms-DOS Kermit: Connecting Your PC to the...            []
# 91953                                      Winning Poker            []
# 99343  The " Weakest Link " Quiz Book: Bk. 2 (Quiz Book)  [1842225952]
# 99776  In Your Face: One Woman's Encounter with Cance...            []
# 99882                                    Petite Anglaise            []
#
#       brand feature                   rank     also_view main_cat  \
# 35               []  17,494,462 in Books (            []    Books
# 79               []   5,976,031 in Books (  [0006593437]    Books
# 80               []  18,893,699 in Books (            []    Books
# 87               []  15,702,609 in Books (            []    Books
# 90               []  14,148,608 in Books (            []    Books
# ...     ...     ...                    ...           ...      ...
# 91842            []  14,426,096 in Books (            []    Books
# 91953            []   4,165,504 in Books (            []    Books
# 99343            []   5,766,064 in Books (            []    Books
# 99776            []  14,263,565 in Books (            []    Books
# 99882            []  19,104,984 in Books (            []    Books
#
#       similar_item date   price        asin imageURL imageURLHighRes
# 35                       $99.98  0000095699       []              []
# 79                               0001543849       []              []
# 80                               0001527355       []              []
# 87                       $73.25  0001148427       []              []
# 90                       $35.99  0001469568       []              []
# ...            ...  ...     ...         ...      ...             ...
# 91842                    $18.32  013952276X       []              []
# 91953                     $5.10  0139610529       []              []
# 99343                     $0.77  014100701X       []              []
# 99776                            0141033339       []              []
# 99882                     $8.85  0141041285       []              []
#
# [437 rows x 18 columns]

# %% [markdown]
# Sidebar: We'll probably have to remove other samples, I just did it as an example. More suggestions are welcomed.

# %% [markdown]
# ### Data Exploratory Analysis (DEA)

# %%
df.shape
# Out:
# (8017, 18)

# %% [markdown]
# The dataframe contains 8017 books and 18 characteristics

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8017 entries, 1 to 9999
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   category         8017 non-null   object
#  1   tech1            8017 non-null   object
#  2   description      8017 non-null   object
#  3   fit              8017 non-null   object
#  4   title            8017 non-null   object
#  5   also_buy         8017 non-null   object
#  6   tech2            8017 non-null   object
#  7   brand            8017 non-null   object
#  8   feature          8017 non-null   object
#  9   rank             8017 non-null   object
#  10  also_view        8017 non-null   object
#  11  main_cat         8017 non-null   object
#  12  similar_item     8017 non-null   object
#  13  date             8017 non-null   object
#  14  price            8017 non-null   object
#  15  asin             8017 non-null   object
#  16  imageURL         8017 non-null   object
#  17  imageURLHighRes  8017 non-null   object
# dtypes: object(18)
# memory usage: 1.2+ MB

# %% [markdown]
# All the data has an object type

# %%
df.describe()
# Out:
#                                             category tech1 description   fit  \
# count                                           8017  8017        8017  8017
# unique                                           485     1        4625     1
# top     [Books, Literature & Fiction, Genre Fiction]                []
# freq                                             453  8017        2445  8017
#
#                title also_buy tech2 brand feature                   rank  \
# count           8017     8017  8017  8017    8017                   8017
# unique          7940     4738     1  4924       1                   8017
# top     Ship of Gold       []                  []  12,887,728 in Books (
# freq               2     3265  8017   160    8017                      1
#
#        also_view main_cat similar_item  date price        asin imageURL  \
# count       8017     8017         8017  8017  8017        8017     8017
# unique      4614        3            1     1  2790        8017        3
# top           []    Books                           0007639562       []
# freq        3347     8009         8017  8017  2021           1     8015
#
#        imageURLHighRes
# count             8017
# unique               3
# top                 []
# freq              8015

# %% [markdown]
# Veryfing if any sample has an `imageURL` or `imageURLHighRes`

# %%
df[df.imageURL.map(len) != 0]
# Out:
#                                        category tech1 description fit  \
# 1886  [Books, Mystery, Thriller &amp; Suspense]                []
# 6777             [Books, Romance, Contemporary]                []
#
#                                              title also_buy tech2  \
# 1886                            The Vulgar Boatman       []
# 6777  Midnight Is A Lonely Place / House Of Echoes       []
#
#               brand feature                                   rank  \
# 1886  Fontana Press      []  1,575,289 in Health &amp; Household (
# 6777  HarperCollins      []      1,150,119 in Health & Household (
#
#          also_view                    main_cat similar_item date price  \
# 1886            []  Health &amp; Personal Care
# 6777  [0007280777]      Health & Personal Care
#
#             asin                                           imageURL  \
# 1886  0006177611  [https://images-na.ssl-images-amazon.com/image...
# 6777  0007645783  [https://images-na.ssl-images-amazon.com/image...
#
#                                         imageURLHighRes
# 1886  [https://images-na.ssl-images-amazon.com/image...
# 6777  [https://images-na.ssl-images-amazon.com/image...

# %%
df[df.imageURLHighRes.map(len) != 0]
# Out:
#                                        category tech1 description fit  \
# 1886  [Books, Mystery, Thriller &amp; Suspense]                []
# 6777             [Books, Romance, Contemporary]                []
#
#                                              title also_buy tech2  \
# 1886                            The Vulgar Boatman       []
# 6777  Midnight Is A Lonely Place / House Of Echoes       []
#
#               brand feature                                   rank  \
# 1886  Fontana Press      []  1,575,289 in Health &amp; Household (
# 6777  HarperCollins      []      1,150,119 in Health & Household (
#
#          also_view                    main_cat similar_item date price  \
# 1886            []  Health &amp; Personal Care
# 6777  [0007280777]      Health & Personal Care
#
#             asin                                           imageURL  \
# 1886  0006177611  [https://images-na.ssl-images-amazon.com/image...
# 6777  0007645783  [https://images-na.ssl-images-amazon.com/image...
#
#                                         imageURLHighRes
# 1886  [https://images-na.ssl-images-amazon.com/image...
# 6777  [https://images-na.ssl-images-amazon.com/image...

# %% [markdown]
# In the first 10000 samples, two images has url to images
